# %% [markdown]
# <a href="https://colab.research.google.com/github/Guhan2348519/demo/blob/main/2348519_CV_LAb7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("/content/drive/MyDrive/anime1.jpeg",0)
print(img.shape)
# Out:
# (212, 237)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gauss_noise = np.zeros((640,480), dtype=np.uint8)
cv2.randn(gauss_noise, 128, 20)
gauss_noise = (gauss_noise * 0.5).astype(np.uint8)

# %%
# Resize the noise matrix to match the image dimensions
gauss_noise_resized = cv2.resize(gauss_noise, (img.shape[1], img.shape[0]))

# Add the resized noise to the image
gn_img = cv2.add(img, gauss_noise_resized)

# %%
gn_img = cv2.add(img, gauss_noise_resized)

# %%
import matplotlib.pyplot as plt

# Create a new figure and set its size
plt.figure(figsize=(15, 5))

# Display the original image
plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')  # Turn off axis labels

# Display the Gaussian noise
plt.subplot(1, 3, 2)
plt.imshow(gauss_noise_resized, cmap='gray')
plt.title('Gaussian Noise')
plt.axis('off')  # Turn off axis labels

# Display the noised image
plt.subplot(1, 3, 3)
plt.imshow(gn_img, cmap='gray')
plt.title('Noised Image')
plt.axis('off')  # Turn off axis labels

plt.show()

# %% [markdown]
# **Gaussian noise **is a statistical noise having the probability density function equal to that of a normal distribution. Random Gaussian function is added to Image function to generate this noise. Since it arises in amplifiers and detectors, it is also known as 'electronic noise'. It is caused by the discrete nature of radiation of warm objects

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

uni_noise = np.zeros(img.shape, dtype=np.uint8)
cv2.randu(uni_noise, 0, 255)
uni_noise = (uni_noise * 0.5).astype(np.uint8)

uni_noise_resized = cv2.resize(uni_noise, (img.shape[1], img.shape[0]))

un_img = cv2.add(img, uni_noise_resized)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.axis("off")
plt.title("Original")

plt.subplot(1, 3, 2)
plt.imshow(uni_noise_resized, cmap='gray')
plt.axis("off")
plt.title("Uniform Noise")

plt.subplot(1, 3, 3)
plt.imshow(un_img, cmap='gray')
plt.axis("off")
plt.title("Noised image")

plt.show()

# %% [markdown]
# Uniform Noise
# Contrary to Gaussian noise, Uniform noise is a signal dependent (unless dithering is caused or applied) that follows a uniform distribution. It is caused by the quantization of the pixels of an image to a number of discrete levels. It is generally created when analog data is converted to digital form, and is not often encountered in real-world imaging systems.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Generate impulse noise matrix
imp_noise = np.zeros(img.shape, dtype=np.uint8)
cv2.randu(imp_noise, 0, 255)
imp_noise = cv2.threshold(imp_noise, 245, 255, cv2.THRESH_BINARY)[1]

# Add the impulse noise to the image
in_img = cv2.add(img, imp_noise)

# Display the three images in subplots
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.axis("off")
plt.title("Original")

plt.subplot(1, 3, 2)
plt.imshow(imp_noise, cmap='gray')
plt.axis("off")
plt.title("Impulse Noise")

plt.subplot(1, 3, 3)
plt.imshow(in_img, cmap='gray')
plt.axis("off")
plt.title("Combined")

plt.show()

# %%
# Apply Gaussian filter to denoise the image
denoised_img = cv2.GaussianBlur(un_img, (5, 5), 0)

# Display the denoised image
plt.imshow(denoised_img, cmap='gray')
plt.axis('off')
plt.title('Denoised Image')
plt.show()

# %%
# Apply median filter for denoising
denoised_median = cv2.medianBlur(in_img, 3)


# Display the original image and denoised images
plt.figure(figsize=(15, 5))

# Original Image
plt.subplot(2, 2, 1)
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title('Original Image')

# Denoised using Median Filter
plt.subplot(2, 2, 2)
plt.imshow(denoised_median, cmap='gray')
plt.axis('off')
plt.title('Median Filter')
# Out:
# Text(0.5, 1.0, 'Median Filter')

# %%
# Apply median filter to denoise the image
denoised_img = cv2.medianBlur(in_img, 3)

# Display the images
plt.figure(figsize=(15, 5))

# Noise image
plt.subplot(1, 3, 1)
plt.imshow(in_img, cmap='gray')
plt.axis("off")
plt.title("Combined")

# Denoised image
plt.subplot(1, 3, 3)
plt.imshow(denoised_img, cmap='gray')
plt.axis("off")
plt.title("Denoised (Median Filter)")

plt.show()
