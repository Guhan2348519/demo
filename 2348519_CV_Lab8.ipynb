# %% [markdown]
# <a href="https://colab.research.google.com/github/Guhan2348519/demo/blob/main/2348519_CV_Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDGE DETECTION USING SOBEL

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpig
# %matplotlib inline

# %%
#read the gray scale image
image = cv2.imread('/content/drive/MyDrive/cvimage.jpeg',cv2.IMREAD_GRAYSCALE)
plt.imshow(image,cmap='gray')

# %%
#define horizontal and Vertical sobel kernels
Gx = np.array([[-1, 0, 1],[-2, 0, 2],[-1, 0, 1]])
Gy = np.array([[-1, -2, -1],[0, 0, 0],[1, 2, 1]])

# %%
#define kernal convolution function
# with image X and filter F
def convolve(X, F):
    # height and width of the image
    X_height = X.shape[0]
    X_width = X.shape[1]

    # height and width of the filter
    F_height = F.shape[0]
    F_width = F.shape[1]

    H = (F_height - 1) // 2
    W = (F_width - 1) // 2

    #output numpy matrix with height and width
    out = np.zeros((X_height, X_width))
    #iterate over all the pixel of image X
    for i in np.arange(H, X_height-H):
        for j in np.arange(W, X_width-W):
            sum = 0
            #iterate over the filter
            for k in np.arange(-H, H+1):
                for l in np.arange(-W, W+1):
                    #get the corresponding value from image and filter
                    a = X[i+k, j+l]
                    w = F[H+k, W+l]
                    sum += (w * a)
            out[i,j] = sum
    #return convolution
    return out

# %%
#normalizing the vectors
sob_x = convolve(image, Gx) / 8.0
sob_y = convolve(image, Gy) / 8.0

# %%
#calculate the gradient magnitude of vectors
sob_out = np.sqrt(np.power(sob_x, 2) + np.power(sob_y, 2))
# mapping values from 0 to 255
sob_out = (sob_out / np.max(sob_out)) * 255

# %%
#output images
cv2.imwrite('sobel.jpg', sob_out)
plt.imshow(sob_out, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %% [markdown]
# EDGE DETECTION USING PREWITTS

# %%
#read the gray scale image
image = cv2.imread('/content/drive/MyDrive/cvimage.jpeg',cv2.IMREAD_GRAYSCALE)
plt.imshow(image,cmap='gray')

# %%
Hx = np.array([[-1, 0, 1],[-1, 0, 1],[-1, 0, 1]])
Hy = np.array([[-1, -1, -1],[0, 0, 0],[1, 1, 1]])

# %%
#normalizing the vectors
pre_x = convolve(image, Hx) / 6.0
pre_y = convolve(image, Hy) / 6.0

# %%
#calculate the gradient magnitude of vectors
pre_out = np.sqrt(np.power(pre_x, 2) + np.power(pre_y, 2))
# mapping values from 0 to 255
pre_out = (pre_out / np.max(pre_out)) * 255
#output images
cv2.imwrite('output/prewitt.jpg', pre_out)
plt.imshow(pre_out, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %% [markdown]
# EDGE DETECTION USING ROBERTS

# %%
# Roberts cross operator kernels
Hx = np.array([[1, 0],[0, -1]])
Hy = np.array([[0, 1],[-1, 0]])

# %%
from scipy.signal import convolve2d

# Convolve image with Roberts cross operator kernels
pre_x = convolve2d(image, Hx, mode='same', boundary='symm') / 6.0
pre_y = convolve2d(image, Hy, mode='same', boundary='symm') / 6.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Calculate the gradient magnitude of vectors
pre_out = np.sqrt(np.power(pre_x, 2) + np.power(pre_y, 2))

# Map values from 0 to 255
pre_out = (pre_out / np.max(pre_out)) * 255

# Output images
cv2.imwrite('output/roberts.jpg', pre_out.astype(np.uint8))
plt.imshow(pre_out, cmap='gray', interpolation='bicubic')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = cv2.imread('/content/drive/MyDrive/cvimage.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply Laplacian filter
laplacian = cv2.Laplacian(image, cv2.CV_64F)

# Convert back to uint8
laplacian = np.uint8(np.absolute(laplacian))

# Show result using matplotlib
plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian Edge Detection')
plt.axis('off')
plt.show()

# %%
from google.colab.patches import cv2_imshow
import cv2

# Read the image in grayscale
image = cv2.imread('/content/drive/MyDrive/cvimage.jpeg', cv2.IMREAD_GRAYSCALE)

# Detect edges using Canny method
edges = cv2.Canny(image, 150, 300)

# Display the image with edges highlighted
image_with_edges = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR
image_with_edges[edges == 255] = (255, 0, 0)  # Highlight edges in blue
cv2_imshow(image_with_edges)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
